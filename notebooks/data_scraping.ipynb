# %%
import os
import re
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse, urljoin

# %%
# --- CONFIGURATION ---
OUTPUT_FOLDER = "knowledge_base_cnn"
MAX_DEPTH = 2           # Réduit à 2 pour éviter de trop s'éloigner du sujet
MAX_PAGES = 30          # Par site
TIMEOUT = 10

# %%
# Headers pour ne pas se faire bloquer
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# %%
# Mots-clés pour valider qu'une page est pertinente
KEYWORDS_CNN = [
    "cnn", "convolution", "pooling", "stride", "padding", "relu", 
    "softmax", "adam", "sgd", "pytorch", "tensorflow", "keras", 
    "layer", "model", "training", "loss", "accuracy", "codecarbon", 
    "emission", "tracker", "inference", "neural"
]

# %%
visited_urls = set()
pages_saved_count = 0

# %%
def nettoyer_nom_fichier(url):
    """Crée un nom de fichier propre à partir de l'URL."""
    parsed = urlparse(url)
    path = parsed.path.strip("/").replace("/", "_")
    if not path: path = "home"
    domain = parsed.netloc.replace("www.", "").replace(".", "_")
    filename = f"{domain}_{path}"
    # Garde seulement les caractères alphanumériques et underscores
    clean_name = "".join([c for c in filename if c.isalnum() or c == '_'])
    return clean_name[:100] + ".txt"

# %%
def extraire_contenu_intelligent(soup):
    """
    Extrait le texte et le CODE en respectant la structure.
    CORRECTION MAJEURE : Préservation de l'indentation et des lignes de code.
    """
    # 1. Nettoyage des balises inutiles
    for balise in soup(["script", "style", "nav", "footer", "header", "aside", "form", "noscript", "svg", "button", "iframe", "ad"]):
        balise.decompose()

    # 2. Trouver le contenu principal
    corps = soup.find('main') or soup.find('article') or soup.find('div', {'role': 'main'}) or soup.find('div', class_='content') or soup.body
    
    if not corps:
        return ""

    contenu_final = []
    textes_vus = set()

    # 3. Parcours intelligent des éléments
    # On ajoute 'code' et les classes spécifiques aux docs techniques
    tags_to_find = ['h1', 'h2', 'h3', 'p', 'pre', 'code', 'div', 'li']
    
    all_elements = corps.find_all(tags_to_find)

    for element in all_elements:
        text_content = ""
        is_code = False
        prefix = ""

        # --- CAS 1 : CODE PYTHON ---
        classes = element.get('class', [])
        
        # Détection améliorée pour TensorFlow, PyTorch, GitHub, etc.
        is_pre_block = element.name == 'pre'
        is_code_div = element.name == 'div' and ('highlight' in classes or 'code' in classes or 'devsite-code-button' in str(classes))
        
        # On ignore les balises 'code' qui sont à l'intérieur d'un 'pre' (pour éviter les doublons)
        if element.name == 'code' and element.find_parent('pre'):
            continue

        if is_pre_block or is_code_div:
            is_code = True
            # --- CORRECTION ICI ---
            # On N'UTILISE PAS separator="\n" pour le code, sinon ça casse tout.
            # On utilise get_text() brut pour garder les espaces et indentations.
            text_content = element.get_text().strip()
        
        # --- CAS 2 : TITRES ---
        elif element.name in ['h1', 'h2', 'h3']:
            text_content = element.get_text(strip=True)
            prefix = "\n\n" + "#" * int(element.name[1]) + " "
        
        # --- CAS 3 : TEXTE NORMAL ---
        elif element.name in ['p', 'li']:
            # On ignore les paragraphes qui sont DANS un tableau ou du code
            if element.find_parent(['table', 'pre', 'div'], class_='highlight'):
                continue
            
            # Pour le texte, on veut des espaces entre les balises inline (comme les liens)
            text_content = element.get_text(" ", strip=True)
            if element.name == 'li':
                prefix = "- "

        # --- FILTRAGE ET AJOUT ---
        if text_content and text_content not in textes_vus:
            
            if is_code:
                # Nettoyage spécifique code : on retire les lignes vides multiples
                lines = [line for line in text_content.splitlines() if line.strip()]
                cleaned_code = "\n".join(lines)
                
                # On ne garde que les blocs de code > 20 caractères
                if len(cleaned_code) > 20:
                    # On vérifie que ce n'est pas juste des commandes shell inutiles
                    if "pip install" in cleaned_code and len(cleaned_code) < 50:
                        continue

                    block = f"\n\n```python\n{cleaned_code}\n```\n\n"
                    contenu_final.append(block)
                    textes_vus.add(text_content) # On ajoute le brut au set pour éviter doublons
            
            else:
                # Pour le texte normal
                if len(text_content) > 30 or element.name.startswith('h'):
                    contenu_final.append(f"{prefix}{text_content}")
                    textes_vus.add(text_content)

    return "\n".join(contenu_final)

# %%
def crawler(url, current_depth, domain_restriction):
    global pages_saved_count
    
    if current_depth > MAX_DEPTH or url in visited_urls:
        return

    visited_urls.add(url)
    print(f"[{current_depth}] Scan: {url}")

    try:
        response = requests.get(url, headers=HEADERS, timeout=TIMEOUT)
        if response.status_code != 200: return

        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Extraction
        texte_propre = extraire_contenu_intelligent(soup)

        # SAUVEGARDE (Uniquement si contenu suffisant)
        if len(texte_propre) > 500:
            filename = nettoyer_nom_fichier(url)
            filepath = os.path.join(OUTPUT_FOLDER, filename)
            
            with open(filepath, "w", encoding="utf-8") as f:
                # ⚠️ IMPORTANT : PLUS DE "SUJET:" NI DE METADATA EN HAUT
                # On met juste l'URL en commentaire tout en bas si besoin
                f.write(texte_propre)
                f.write(f"\n\n# Source: {url}")
            
            print(f"   -> Sauvegardé : {filename} ({len(texte_propre)} chars)")
            pages_saved_count += 1
        else:
            print("   -> Ignoré (Contenu trop court/vide)")

        # NAVIGATION (Récursive)
        if current_depth < MAX_DEPTH:
            for lien in soup.find_all('a', href=True):
                full_url = urljoin(url, lien['href']).split('#')[0]
                
                # On reste sur le même domaine et on évite les doublons
                if domain_restriction in full_url and full_url not in visited_urls:
                    # Filtre simple sur les mots clés dans l'URL pour rester pertinent
                    if any(kw in full_url.lower() for kw in KEYWORDS_CNN) or "tutorial" in full_url:
                        crawler(full_url, current_depth + 1, domain_restriction)

    except Exception as e:
        print(f"   -> Erreur: {e}")

# %%
# --- LANCEMENT ---
if __name__ == "__main__":
    if not os.path.exists(OUTPUT_FOLDER):
        os.makedirs(OUTPUT_FOLDER)
    
    # Liste ciblée (Docs officielles + Tutoriels fiables)
    urls_cibles = [
        # --- 1. LES INDISPENSABLES (DOCS OFFICIELLES) ---
    # Ces pages sont "propres" et contiennent le code exact que l'IA doit apprendre.
    
    # TensorFlow / Keras (Le standard pour débuter)
    "https://www.tensorflow.org/tutorials/images/cnn",
    "https://www.tensorflow.org/tutorials/images/classification",
    "https://www.tensorflow.org/tutorials/images/data_augmentation",
    "https://www.tensorflow.org/tutorials/images/transfer_learning",
    "https://www.tensorflow.org/guide/keras/functional",  # Pour les architectures complexes

    # PyTorch (Le standard recherche/industrie)
    "https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html",
    "https://pytorch.org/tutorials/beginner/basics/buildmodel_tutorial.html",
    "https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html",
    "https://pytorch.org/tutorials/recipes/recipes/defining_a_neural_network.html",

    # --- 2. THÉORIE APPROFONDIE (BIBLE DES CNN) ---
    # Stanford CS231n : C'est la référence mondiale. Très riche en texte explicatif.
    "https://cs231n.github.io/convolutional-networks/",
    "https://cs231n.github.io/neural-networks-1/",
    "https://cs231n.github.io/neural-networks-2/",
    "https://cs231n.github.io/optimization-1/",
    
    # MIT Deep Learning
    "http://introtodeeplearning.com/", 

    # --- 3. TUTORIELS PRATIQUES & CODE ---
    # Machine Learning Mastery (Très facile à scraper, format clair)
    "https://machinelearningmastery.com/convolutional-layers-for-deep-learning-neural-networks/",
    "https://machinelearningmastery.com/how-to-develop-a-cnn-from-scratch-for-cifar-10-photo-classification/",
    "https://machinelearningmastery.com/image-augmentation-deep-learning-keras/",
    
    # Papers with Code (Pour relier théorie et implémentation)
    "https://paperswithcode.com/method/cnn",
    "https://paperswithcode.com/method/resnet",
    
    # --- 4. GREEN AI & MLOps (Ton exigence spécifique) ---
    # CodeCarbon & Mesure d'énergie
    "https://mlco2.github.io/codecarbon/usage.html",
    "https://mlco2.github.io/codecarbon/methodology.html",
    "https://mlco2.github.io/codecarbon/parameters.html",
    
    # Hugging Face (Documentation efficace)
    "https://huggingface.co/docs/transformers/tasks/image_classification",

    # --- 5. MATHÉMATIQUES & CONCEPTS CLÉS ---
    # Explications visuelles des convolutions
    "https://poloclub.github.io/cnn-explainer/",  # Attention: bcp de visuel, peut-être dur à scraper
    "https://distill.pub/2017/feature-visualization/", # Excellent mais complexe techniquement
    
    # --- 6. ARCHITECTURES CÉLÈBRES ---
    "https://iq.opengenus.org/vgg16/",
    "https://iq.opengenus.org/resnet50-architecture/",
    "https://iq.opengenus.org/mobile-net-architecture/"
    ]

    print("--- Démarrage du Scraping Optimisé ---")
    
    for url in urls_cibles:
        domain = urlparse(url).netloc
        crawler(url, 0, domain)
    
    print(f"\nTerminé ! {pages_saved_count} pages extraites avec succès.")
# Out:
# --- Démarrage du Scraping Optimisé ---
# [0] Scan: https://www.tensorflow.org/tutorials/images/cnn
#    -> Sauvegardé : tensorflow_org_tutorials_images_cnn.txt (19340 chars)
# [1] Scan: https://www.tensorflow.org/
#    -> Sauvegardé : tensorflow_org_home.txt (3660 chars)
# [2] Scan: https://www.tensorflow.org/install
#    -> Sauvegardé : tensorflow_org_install.txt (1768 chars)
# [2] Scan: https://www.tensorflow.org/tutorials
#    -> Sauvegardé : tensorflow_org_tutorials.txt (3233 chars)
# [2] Scan: https://www.tensorflow.org/js
#    -> Sauvegardé : tensorflow_org_js.txt (1121 chars)
# [2] Scan: https://www.tensorflow.org/guide/data
#    -> Sauvegardé : tensorflow_org_guide_data.txt (69511 chars)
# [2] Scan: https://www.tensorflow.org/tfx
#    -> Sauvegardé : tensorflow_org_tfx.txt (1817 chars)
# [2] Scan: https://www.tensorflow.org/guide/keras
#    -> Sauvegardé : tensorflow_org_guide_keras.txt (5068 chars)
# [2] Scan: https://www.tensorflow.org/datasets
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://www.tensorflow.org/tensorboard
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://www.tensorflow.org/resources/models-datasets
#    -> Sauvegardé : tensorflow_org_resources_modelsdatasets.txt (756 chars)
# [2] Scan: https://www.tensorflow.org/resources/libraries-extensions
#    -> Sauvegardé : tensorflow_org_resources_librariesextensions.txt (6229 chars)
# [2] Scan: https://www.tensorflow.org/resources/tools
#    -> Sauvegardé : tensorflow_org_resources_tools.txt (1444 chars)
# [2] Scan: https://www.tensorflow.org/community
#    -> Sauvegardé : tensorflow_org_community.txt (1800 chars)
# [2] Scan: https://www.tensorflow.org/resources/learn-ml
#    -> Sauvegardé : tensorflow_org_resources_learnml.txt (12137 chars)
# [2] Scan: https://www.tensorflow.org/subscribe/latest
#    -> Sauvegardé : tensorflow_org_subscribe_latest.txt (528 chars)
# [1] Scan: https://www.tensorflow.org/learn
#    -> Sauvegardé : tensorflow_org_learn.txt (3463 chars)
# [2] Scan: https://www.tensorflow.org/guide/keras/preprocessing_layers
#    -> Sauvegardé : tensorflow_org_guide_keras_preprocessing_layers.txt (24663 chars)
# [2] Scan: https://www.tensorflow.org/tfx/guide/tfdv
#    -> Sauvegardé : tensorflow_org_tfx_guide_tfdv.txt (11537 chars)
# [2] Scan: https://www.tensorflow.org/tfx/guide/tft
#    -> Sauvegardé : tensorflow_org_tfx_guide_tft.txt (1120 chars)
# [2] Scan: https://www.tensorflow.org/responsible_ai
#    -> Sauvegardé : tensorflow_org_responsible_ai.txt (5233 chars)
# [2] Scan: https://www.tensorflow.org/guide/basics
#    -> Sauvegardé : tensorflow_org_guide_basics.txt (26150 chars)
# [2] Scan: https://www.tensorflow.org/tfx/guide/tfma
#    -> Sauvegardé : tensorflow_org_tfx_guide_tfma.txt (1726 chars)
# [2] Scan: https://www.tensorflow.org/hub
#    -> Sauvegardé : tensorflow_org_hub.txt (940 chars)
# [2] Scan: https://www.tensorflow.org/guide/model_garden
#    -> Sauvegardé : tensorflow_org_guide_model_garden.txt (5985 chars)
# [2] Scan: https://www.tensorflow.org/tfx/guide/serving
#    -> Sauvegardé : tensorflow_org_tfx_guide_serving.txt (895 chars)
# [1] Scan: https://www.tensorflow.org/guide/keras/overview
#    -> Sauvegardé : tensorflow_org_guide_keras_overview.txt (5068 chars)
# [2] Scan: https://www.tensorflow.org/guide
#    -> Sauvegardé : tensorflow_org_guide.txt (2864 chars)
# [2] Scan: https://www.tensorflow.org/guide/core
#    -> Sauvegardé : tensorflow_org_guide_core.txt (4640 chars)
# [2] Scan: https://www.tensorflow.org/guide/keras/sequential_model
#    -> Sauvegardé : tensorflow_org_guide_keras_sequential_model.txt (14595 chars)
# [2] Scan: https://www.tensorflow.org/guide/keras/functional_api
#    -> Sauvegardé : tensorflow_org_guide_keras_functional_api.txt (37608 chars)
# [2] Scan: https://www.tensorflow.org/guide/keras/making_new_layers_and_models_via_subclassing
#    -> Sauvegardé : tensorflow_org_guide_keras_making_new_layers_and_models_via_subclassing.txt (23013 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/keras/callbacks
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_keras_callbacks.txt (1672 chars)
# [2] Scan: https://www.tensorflow.org/guide/keras/writing_your_own_callbacks
#    -> Sauvegardé : tensorflow_org_guide_keras_writing_your_own_callbacks.txt (23183 chars)
# [2] Scan: https://www.tensorflow.org/guide/keras/distributed_training
#    -> Sauvegardé : tensorflow_org_guide_keras_distributed_training.txt (28636 chars)
# [2] Scan: https://www.tensorflow.org/guide/keras/training_with_built_in_methods
#    -> Sauvegardé : tensorflow_org_guide_keras_training_with_built_in_methods.txt (48259 chars)
# [2] Scan: https://www.tensorflow.org/guide/keras/customizing_what_happens_in_fit
#    -> Sauvegardé : tensorflow_org_guide_keras_customizing_what_happens_in_fit.txt (17315 chars)
# [2] Scan: https://www.tensorflow.org/guide/keras/functional
#    -> Sauvegardé : tensorflow_org_guide_keras_functional.txt (37608 chars)
# [2] Scan: https://www.tensorflow.org/guide/keras/custom_layers_and_models
#    -> Sauvegardé : tensorflow_org_guide_keras_custom_layers_and_models.txt (23013 chars)
# [2] Scan: https://www.tensorflow.org/guide/keras/save_and_serialize
#    -> Sauvegardé : tensorflow_org_guide_keras_save_and_serialize.txt (32231 chars)
# [2] Scan: https://www.tensorflow.org/guide/keras/writing_a_training_loop_from_scratch
#    -> Sauvegardé : tensorflow_org_guide_keras_writing_a_training_loop_from_scratch.txt (22904 chars)
# [2] Scan: https://www.tensorflow.org/guide/keras/rnn
#    -> Sauvegardé : tensorflow_org_guide_keras_rnn.txt (24518 chars)
# [2] Scan: https://www.tensorflow.org/guide/keras/masking_and_padding
#    -> Sauvegardé : tensorflow_org_guide_keras_masking_and_padding.txt (13913 chars)
# [2] Scan: https://www.tensorflow.org/guide/keras/custom_callback
#    -> Sauvegardé : tensorflow_org_guide_keras_custom_callback.txt (23183 chars)
# [2] Scan: https://www.tensorflow.org/guide/keras/transfer_learning
#    -> Sauvegardé : tensorflow_org_guide_keras_transfer_learning.txt (30755 chars)
# [1] Scan: https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_keras_layers_Conv2D.txt (5667 chars)
# [2] Scan: https://www.tensorflow.org/api_docs
#    -> Sauvegardé : tensorflow_org_api_docs.txt (1215 chars)
# [2] Scan: https://www.tensorflow.org/api
#    -> Sauvegardé : tensorflow_org_api.txt (729 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf.txt (21161 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/keras/Layer
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_keras_Layer.txt (14070 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/keras/Operation
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_keras_Operation.txt (1870 chars)
# [2] Scan: https://www.tensorflow.org/guide/migrate/model_mapping
#    -> Sauvegardé : tensorflow_org_guide_migrate_model_mapping.txt (35364 chars)
# [2] Scan: https://www.tensorflow.org/guide/effective_tf2
#    -> Sauvegardé : tensorflow_org_guide_effective_tf2.txt (26863 chars)
# [2] Scan: https://www.tensorflow.org/guide/tpu
#    -> Sauvegardé : tensorflow_org_guide_tpu.txt (22666 chars)
# [2] Scan: https://www.tensorflow.org/guide/function
#    -> Sauvegardé : tensorflow_org_guide_function.txt (94091 chars)
# [2] Scan: https://www.tensorflow.org/model_optimization/guide/pruning/pruning_for_on_device_inference
#    -> Sauvegardé : tensorflow_org_model_optimization_guide_pruning_pruning_for_on_device_inference.txt (15594 chars)
# [2] Scan: https://www.tensorflow.org/tutorials/customization/custom_layers
#    -> Sauvegardé : tensorflow_org_tutorials_customization_custom_layers.txt (6806 chars)
# [2] Scan: https://www.tensorflow.org/tutorials/images/classification
#    -> Sauvegardé : tensorflow_org_tutorials_images_classification.txt (16825 chars)
# [2] Scan: https://www.tensorflow.org/tutorials/images/data_augmentation
#    -> Sauvegardé : tensorflow_org_tutorials_images_data_augmentation.txt (34544 chars)
# [2] Scan: https://www.tensorflow.org/tutorials/generative/autoencoder
#    -> Sauvegardé : tensorflow_org_tutorials_generative_autoencoder.txt (38780 chars)
# [2] Scan: https://www.tensorflow.org/tutorials/generative/pix2pix
#    -> Sauvegardé : tensorflow_org_tutorials_generative_pix2pix.txt (63473 chars)
# [1] Scan: https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_keras_layers_MaxPool2D.txt (4537 chars)
# [2] Scan: https://www.tensorflow.org/model_optimization/guide/pruning/pruning_with_sparsity_2_by_4
#    -> Sauvegardé : tensorflow_org_model_optimization_guide_pruning_pruning_with_sparsity_2_by_4.txt (14951 chars)
# [2] Scan: https://www.tensorflow.org/tutorials/load_data/images
#    -> Sauvegardé : tensorflow_org_tutorials_load_data_images.txt (29092 chars)
# [2] Scan: https://www.tensorflow.org/tutorials/distribute/custom_training
#    -> Sauvegardé : tensorflow_org_tutorials_distribute_custom_training.txt (22420 chars)
# [1] Scan: https://www.tensorflow.org/tutorials/quickstart/advanced
#    -> Sauvegardé : tensorflow_org_tutorials_quickstart_advanced.txt (21869 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/data
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_data.txt (1399 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/keras
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_keras.txt (2067 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/GradientTape
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_GradientTape.txt (12381 chars)
# [0] Scan: https://www.tensorflow.org/tutorials/images/transfer_learning
#    -> Sauvegardé : tensorflow_org_tutorials_images_transfer_learning.txt (192209 chars)
# [1] Scan: https://www.tensorflow.org/api_docs/python/tf/data/Dataset
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_data_Dataset.txt (85969 chars)
# [2] Scan: https://www.tensorflow.org/guide/data_performance
#    -> Sauvegardé : tensorflow_org_guide_data_performance.txt (36842 chars)
# [2] Scan: https://www.tensorflow.org/guide/extension_type
#    -> Sauvegardé : tensorflow_org_guide_extension_type.txt (41463 chars)
# [2] Scan: https://www.tensorflow.org/guide/migrate/migrating_estimator
#    -> Sauvegardé : tensorflow_org_guide_migrate_migrating_estimator.txt (6970 chars)
# [2] Scan: https://www.tensorflow.org/guide/distributed_training
#    -> Sauvegardé : tensorflow_org_guide_distributed_training.txt (41016 chars)
# [2] Scan: https://www.tensorflow.org/tutorials/distribute/input
#    -> Sauvegardé : tensorflow_org_tutorials_distribute_input.txt (126724 chars)
# [2] Scan: https://www.tensorflow.org/tutorials/distribute/parameter_server_training
#    -> Sauvegardé : tensorflow_org_tutorials_distribute_parameter_server_training.txt (4188 chars)
# [2] Scan: https://www.tensorflow.org/tutorials/load_data/csv
#    -> Sauvegardé : tensorflow_org_tutorials_load_data_csv.txt (48914 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/data/TextLineDataset
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_data_TextLineDataset.txt (85189 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/data/FixedLengthRecordDataset
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_data_FixedLengthRecordDataset.txt (85326 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/TypeSpec
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_TypeSpec.txt (3852 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/Tensor
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_Tensor.txt (16521 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/sparse/SparseTensor
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_sparse_SparseTensor.txt (8170 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/RaggedTensor
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_RaggedTensor.txt (42980 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/TensorArray
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_TensorArray.txt (9067 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/data/Options
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_data_Options.txt (4241 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/TensorShape
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_TensorShape.txt (15824 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/dtypes
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_dtypes.txt (2798 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/dtypes/DType
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_dtypes_DType.txt (4364 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/constant
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_constant.txt (4117 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/random/set_seed
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_random_set_seed.txt (5275 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/py_function
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_py_function.txt (6146 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/numpy_function
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_numpy_function.txt (5534 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/data/experimental/dense_to_sparse_batch
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_data_experimental_dense_to_sparse_batch.txt (2397 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/train/CheckpointManager
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_train_CheckpointManager.txt (5651 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_train_Checkpoint.txt (13418 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/data/Iterator
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_data_Iterator.txt (2976 chars)
# [1] Scan: https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image_dataset_from_directory
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_keras_preprocessing_image_dataset_from_directory.txt (6213 chars)
# [2] Scan: https://www.tensorflow.org/tutorials/images/transfer_learning_with_hub
#    -> Sauvegardé : tensorflow_org_tutorials_images_transfer_learning_with_hub.txt (10850 chars)
# [2] Scan: https://www.tensorflow.org/hub/tutorials/tf2_image_retraining
#    -> Sauvegardé : tensorflow_org_hub_tutorials_tf2_image_retraining.txt (9536 chars)
# [1] Scan: https://www.tensorflow.org/api_docs/python/tf/data/experimental/cardinality
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_data_experimental_cardinality.txt (1915 chars)
# [2] Scan: https://www.tensorflow.org/guide/migrate
#    -> Sauvegardé : tensorflow_org_guide_migrate.txt (2512 chars)
# [2] Scan: https://www.tensorflow.org/text/tutorials/classify_text_with_bert
#    -> Sauvegardé : tensorflow_org_text_tutorials_classify_text_with_bert.txt (17973 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/data/experimental
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_data_experimental.txt (5456 chars)
# [1] Scan: https://www.tensorflow.org/tutorials/keras/overfit_and_underfit
#    -> Sauvegardé : tensorflow_org_tutorials_keras_overfit_and_underfit.txt (22355 chars)
# [2] Scan: https://www.tensorflow.org/tutorials/keras/text_classification_with_hub
#    -> Sauvegardé : tensorflow_org_tutorials_keras_text_classification_with_hub.txt (8950 chars)
# [2] Scan: https://www.tensorflow.org/tutorials/keras/regression
#    -> Sauvegardé : tensorflow_org_tutorials_keras_regression.txt (16176 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/data/experimental/CsvDataset
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_data_experimental_CsvDataset.txt (87100 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_keras_layers_Dense.txt (4041 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/schedules
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_keras_optimizers_schedules.txt (1392 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/schedules/InverseTimeDecay
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_keras_optimizers_schedules_InverseTimeDecay.txt (2997 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_keras_callbacks_EarlyStopping.txt (7361 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/TensorBoard
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_keras_callbacks_TensorBoard.txt (9381 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/keras/Model
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_keras_Model.txt (33883 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Ftrl
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_keras_optimizers_Ftrl.txt (10173 chars)
# [2] Scan: https://www.tensorflow.org/addons/api_docs/python/tfa/optimizers/AdamW
#    -> Sauvegardé : tensorflow_org_addons_api_docs_python_tfa_optimizers_AdamW.txt (9562 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_keras_layers_Dropout.txt (2947 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/keras/layers/BatchNormalization
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_keras_layers_BatchNormalization.txt (7000 chars)
# [1] Scan: https://www.tensorflow.org/api_docs/python/tf/keras/applications/MobileNetV2
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_keras_applications_MobileNetV2.txt (3734 chars)
# [2] Scan: https://www.tensorflow.org/guide/estimator
#    -> Sauvegardé : tensorflow_org_guide_estimator.txt (70887 chars)
# [2] Scan: https://www.tensorflow.org/tutorials/generative/adversarial_fgsm
#    -> Sauvegardé : tensorflow_org_tutorials_generative_adversarial_fgsm.txt (24907 chars)
# [2] Scan: https://www.tensorflow.org/tutorials/images/segmentation
#    -> Sauvegardé : tensorflow_org_tutorials_images_segmentation.txt (29850 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/keras/Input
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_keras_Input.txt (2807 chars)
# [1] Scan: https://www.tensorflow.org/api_docs/python/tf/keras/layers/GlobalAveragePooling2D
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_keras_layers_GlobalAveragePooling2D.txt (3116 chars)
# [2] Scan: https://www.tensorflow.org/federated/tutorials/simulations_with_accelerators
#    -> Sauvegardé : tensorflow_org_federated_tutorials_simulations_with_accelerators.txt (40441 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/math/reduce_mean
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_math_reduce_mean.txt (2203 chars)
# [1] Scan: https://www.tensorflow.org/api_docs/python/tf/Variable
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_Variable.txt (26173 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/VariableSynchronization
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_VariableSynchronization.txt (1808 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/compat/v1/VariableAggregation
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_compat_v1_VariableAggregation.txt (1897 chars)
# [2] Scan: https://www.tensorflow.org/guide/migrate/migrating_checkpoints
#    -> Sauvegardé : tensorflow_org_guide_migrate_migrating_checkpoints.txt (28662 chars)
# [2] Scan: https://www.tensorflow.org/guide/autodiff
#    -> Sauvegardé : tensorflow_org_guide_autodiff.txt (27345 chars)
# [2] Scan: https://www.tensorflow.org/guide/variable
#    -> Sauvegardé : tensorflow_org_guide_variable.txt (18529 chars)
# [2] Scan: https://www.tensorflow.org/guide/advanced_autodiff
#    -> Sauvegardé : tensorflow_org_guide_advanced_autodiff.txt (30405 chars)
# [2] Scan: https://www.tensorflow.org/tutorials/optimization/compression
#    -> Sauvegardé : tensorflow_org_tutorials_optimization_compression.txt (26022 chars)
# [2] Scan: https://www.tensorflow.org/tutorials/distribute/multi_worker_with_ctl
#    -> Sauvegardé : tensorflow_org_tutorials_distribute_multi_worker_with_ctl.txt (17756 chars)
# [2] Scan: https://www.tensorflow.org/tutorials/generative/style_transfer
#    -> Sauvegardé : tensorflow_org_tutorials_generative_style_transfer.txt (170438 chars)
# [2] Scan: https://www.tensorflow.org/tutorials/generative/data_compression
#    -> Sauvegardé : tensorflow_org_tutorials_generative_data_compression.txt (23702 chars)
# [2] Scan: https://www.tensorflow.org/probability/examples/Learnable_Distributions_Zoo
#    -> Sauvegardé : tensorflow_org_probability_examples_Learnable_Distributions_Zoo.txt (10605 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/Module
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_Module.txt (4970 chars)
# [2] Scan: https://www.tensorflow.org/guide/checkpoint
#    -> Sauvegardé : tensorflow_org_guide_checkpoint.txt (11238 chars)
# [2] Scan: https://www.tensorflow.org/guide/saved_model
#    -> Sauvegardé : tensorflow_org_guide_saved_model.txt (22635 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/function
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_function.txt (12209 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/VariableAggregation
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_VariableAggregation.txt (1832 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/Variable/SaveSliceInfo
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_Variable_SaveSliceInfo.txt (1996 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/IndexedSlices
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_IndexedSlices.txt (2655 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/compat/v1/Session
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/scatter_nd
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_scatter_nd.txt (3943 chars)
# [2] Scan: https://www.tensorflow.org/api_docs/python/tf/raw_ops/Any
#    -> Sauvegardé : tensorflow_org_api_docs_python_tf_raw_ops_Any.txt (1337 chars)
# [0] Scan: https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html
#    -> Sauvegardé : pytorch_org_tutorials_beginner_blitz_cifar10_tutorialhtml.txt (13400 chars)
# [1] Scan: https://pytorch.org/
#    -> Sauvegardé : pytorch_org_home.txt (2766 chars)
# [2] Scan: https://pytorch.org/get-started/locally/
#    -> Sauvegardé : pytorch_org_getstarted_locally.txt (7647 chars)
# [2] Scan: https://pytorch.org/blog/accelerating-on-device-ml-inference-with-executorch-and-arm-sme2/
#    -> Sauvegardé : pytorch_org_blog_acceleratingondevicemlinferencewithexecutorchandarmsme2.txt (18652 chars)
# [2] Scan: https://pytorch.org/blog/category/blog/
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/blog/pytorch-2-10-release-blog/
#    -> Sauvegardé : pytorch_org_blog_pytorch210releaseblog.txt (5517 chars)
# [2] Scan: https://pytorch.org/blog/pytorch-foundation-in-2025-a-year-in-review/
#    -> Sauvegardé : pytorch_org_blog_pytorchfoundationin2025ayearinreview.txt (14279 chars)
# [2] Scan: https://pytorch.org/blog/category/announcements/
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/join
#    -> Sauvegardé : pytorch_org_join.txt (2965 chars)
# [2] Scan: https://pytorch.org/get-started/previous-versions
#    -> Sauvegardé : pytorch_org_getstarted_previousversions.txt (55070 chars)
# [2] Scan: https://pytorch.org/get-started/previous-versions/
#    -> Sauvegardé : pytorch_org_getstarted_previousversions.txt (55070 chars)
# [2] Scan: https://landscape.pytorch.org/
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/case-studies/
#    -> Sauvegardé : pytorch_org_casestudies.txt (4084 chars)
# [2] Scan: https://pytorch.org/docs
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/tutorials
#    -> Sauvegardé : pytorch_org_tutorials.txt (26567 chars)
# [2] Scan: https://pytorch.org/resources
#    -> Sauvegardé : pytorch_org_resources.txt (1040 chars)
# [2] Scan: https://pytorch.org/tutorials/
#    -> Sauvegardé : pytorch_org_tutorials.txt (26567 chars)
# [2] Scan: https://pytorch.org/tutorials/beginner/basics/intro.html
#    -> Sauvegardé : pytorch_org_tutorials_beginner_basics_introhtml.txt (1814 chars)
# [2] Scan: https://docs.pytorch.org/tutorials/recipes_index.html
#    -> Sauvegardé : docs_pytorch_org_tutorials_recipes_indexhtml.txt (8036 chars)
# [2] Scan: https://pytorch.org/tutorials/beginner/introyt.html
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/webinars/
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/join-ecosystem
#    -> Sauvegardé : pytorch_org_joinecosystem.txt (1286 chars)
# [2] Scan: https://pytorch.org/community-hub/
#    -> Sauvegardé : pytorch_org_communityhub.txt (942 chars)
# [2] Scan: https://discuss.pytorch.org/
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/resources/
#    -> Sauvegardé : pytorch_org_resources.txt (1040 chars)
# [2] Scan: https://pytorch.org/meeting-calendar/
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/contributor-awards/
#    -> Sauvegardé : pytorch_org_contributorawards.txt (2290 chars)
# [2] Scan: https://pytorch.org/programs/ambassadors/
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/projects/
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/projects/pytorch/
#    -> Sauvegardé : pytorch_org_projects_pytorch.txt (1372 chars)
# [2] Scan: https://pytorch.org/projects/vllm/
#    -> Sauvegardé : pytorch_org_projects_vllm.txt (819 chars)
# [2] Scan: https://pytorch.org/projects/deepspeed/
#    -> Sauvegardé : pytorch_org_projects_deepspeed.txt (1076 chars)
# [2] Scan: https://pytorch.org/projects/ray/
#    -> Sauvegardé : pytorch_org_projects_ray.txt (813 chars)
# [2] Scan: https://pytorch.org/projects/host-your-project/
#    -> Sauvegardé : pytorch_org_projects_hostyourproject.txt (630 chars)
# [2] Scan: https://pytorch.org/docs/stable/index.html
#    -> Sauvegardé : pytorch_org_docs_stable_indexhtml.txt (3889 chars)
# [2] Scan: https://pytorch.org/domains/
#    -> Sauvegardé : pytorch_org_domains.txt (1948 chars)
# [2] Scan: https://pytorch.org/blog/
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/announcements
#    -> Sauvegardé : pytorch_org_announcements.txt (4359 chars)
# [2] Scan: https://pytorch.org/events/
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/newsletter/
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/foundation/
#    -> Sauvegardé : pytorch_org_foundation.txt (2360 chars)
# [2] Scan: https://pytorch.org/members
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/governing-board/
#    -> Sauvegardé : pytorch_org_governingboard.txt (6009 chars)
# [2] Scan: https://pytorch.org/tac/
#    -> Sauvegardé : pytorch_org_tac.txt (6172 chars)
# [2] Scan: https://pytorch.org/credits/
#    -> Sauvegardé : pytorch_org_credits.txt (2773 chars)
# [2] Scan: https://pytorch.org/staff/
#    -> Sauvegardé : pytorch_org_staff.txt (6831 chars)
# [2] Scan: https://pytorch.org/contact/
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/wp-content/uploads/2025/09/pytorch_brand_guide_091925a.pdf
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/join/
#    -> Sauvegardé : pytorch_org_join.txt (2965 chars)
# [1] Scan: https://pytorch.org/get-started/locally
#    -> Sauvegardé : pytorch_org_getstarted_locally.txt (7647 chars)
# [2] Scan: https://pytorch.org/get-started/pytorch-2-x/
#    -> Sauvegardé : pytorch_org_getstarted_pytorch2x.txt (36128 chars)
# [2] Scan: https://pytorch.org/get-started/cloud-partners/
#    -> Sauvegardé : pytorch_org_getstarted_cloudpartners.txt (14232 chars)
# [2] Scan: https://pytorch.org/get-started/executorch/
#    -> Sauvegardé : pytorch_org_getstarted_executorch.txt (894 chars)
# [2] Scan: https://pytorch.org/tutorials/beginner/blitz/tensor_tutorial.html?highlight=cuda&__hstc=76629258.724dacd2270c1ae797f3a62ecd655d50.1746547368336.1746547368336.1746547368336.1&__hssc=76629258.10.1746547368336&__hsfp=2230748894
#    -> Sauvegardé : pytorch_org_tutorials_beginner_blitz_tensor_tutorialhtml.txt (6616 chars)
# [1] Scan: https://docs.pytorch.org/tutorials
#    -> Sauvegardé : docs_pytorch_org_tutorials.txt (26567 chars)
# [2] Scan: https://pytorch.org/tutorials/recipes/recipes_index.html
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/community-events/
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://docs.pytorch.org/docs/stable/index.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_indexhtml.txt (3889 chars)
# [2] Scan: https://pytorch.org/domains
#    -> Sauvegardé : pytorch_org_domains.txt (1948 chars)
# [2] Scan: https://pytorch.org/events
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/newsletter
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/foundation
#    -> Sauvegardé : pytorch_org_foundation.txt (2360 chars)
# [2] Scan: https://pytorch.org/governing-board
#    -> Sauvegardé : pytorch_org_governingboard.txt (6009 chars)
# [2] Scan: https://pytorch.org/tac
#    -> Sauvegardé : pytorch_org_tac.txt (6172 chars)
# [2] Scan: https://pytorch.org/credits
#    -> Sauvegardé : pytorch_org_credits.txt (2773 chars)
# [2] Scan: https://pytorch.org/staff
#    -> Sauvegardé : pytorch_org_staff.txt (6831 chars)
# [2] Scan: https://pytorch.org/contact
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://dev-discuss.pytorch.org/
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://docs.pytorch.org/tutorials/beginner/mosaic_memory_profiling_tutorial.html
#    -> Sauvegardé : docs_pytorch_org_tutorials_beginner_mosaic_memory_profiling_tutorialhtml.txt (3151314 chars)
# [2] Scan: https://docs.pytorch.org/tutorials/intermediate/variable_length_attention_tutorial.html
#    -> Sauvegardé : docs_pytorch_org_tutorials_intermediate_variable_length_attention_tutorialhtml.txt (10250 chars)
# [2] Scan: https://docs.pytorch.org/tutorials/recipes/debug_mode_tutorial.html
#    -> Sauvegardé : docs_pytorch_org_tutorials_recipes_debug_mode_tutorialhtml.txt (14316 chars)
# [2] Scan: https://docs.pytorch.org/tutorials/advanced/cpp_custom_ops_sycl.html
#    -> Sauvegardé : docs_pytorch_org_tutorials_advanced_cpp_custom_ops_syclhtml.txt (9297 chars)
# [2] Scan: https://docs.pytorch.org/tutorials/advanced/cpp_custom_ops.html
#    -> Sauvegardé : docs_pytorch_org_tutorials_advanced_cpp_custom_opshtml.txt (31564 chars)
# [2] Scan: https://docs.pytorch.org/beginner/basics/intro.html
# [2] Scan: https://docs.pytorch.org/recipes_index.html
# [2] Scan: https://docs.pytorch.org/beginner/introyt/introyt_index.html
# [2] Scan: https://docs.pytorch.org/beginner/pytorch_with_examples.html
# [2] Scan: https://docs.pytorch.org/beginner/nn_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/tensorboard_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/pinmem_nonblock.html
# [2] Scan: https://docs.pytorch.org/beginner/understanding_leaf_vs_nonleaf_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/visualizing_gradients_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/torchvision_tutorial.html
# [2] Scan: https://docs.pytorch.org/beginner/transfer_learning_tutorial.html
# [2] Scan: https://docs.pytorch.org/beginner/fgsm_tutorial.html
# [2] Scan: https://docs.pytorch.org/beginner/dcgan_faces_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/spatial_transformer_tutorial.html
# [2] Scan: https://docs.pytorch.org/advanced/usb_semisup_learn.html
# [2] Scan: https://docs.pytorch.org/beginner/audio_io_tutorial.html
# [2] Scan: https://docs.pytorch.org/beginner/audio_resampling_tutorial.html
# [2] Scan: https://docs.pytorch.org/beginner/audio_data_augmentation_tutorial.html
# [2] Scan: https://docs.pytorch.org/beginner/audio_feature_extractions_tutorial.html
# [2] Scan: https://docs.pytorch.org/beginner/audio_feature_augmentation_tutorial.html
# [2] Scan: https://docs.pytorch.org/beginner/audio_datasets_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/speech_recognition_pipeline_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/speech_command_classification_with_torchaudio_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/text_to_speech_with_torchaudio.html
# [2] Scan: https://docs.pytorch.org/intermediate/forced_alignment_with_torchaudio_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/char_rnn_classification_tutorial
# [2] Scan: https://docs.pytorch.org/intermediate/char_rnn_generation_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/seq2seq_translation_tutorial.html
# [2] Scan: https://docs.pytorch.org/beginner/onnx/export_simple_model_to_onnx_tutorial.html
# [2] Scan: https://docs.pytorch.org/beginner/onnx/onnx_registry_tutorial.html
# [2] Scan: https://docs.pytorch.org/beginner/onnx/export_control_flow_model_to_onnx_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/reinforcement_q_learning.html
# [2] Scan: https://docs.pytorch.org/intermediate/reinforcement_ppo.html
# [2] Scan: https://docs.pytorch.org/intermediate/mario_rl_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/dqn_with_rnn_tutorial.html
# [2] Scan: https://docs.pytorch.org/advanced/coding_ddpg.html
# [2] Scan: https://docs.pytorch.org/advanced/pendulum.html
# [2] Scan: https://docs.pytorch.org/beginner/profiler.html
# [2] Scan: https://docs.pytorch.org/beginner/hta_intro_tutorial.html
# [2] Scan: https://docs.pytorch.org/beginner/hta_trace_diff_tutorial.html
# [2] Scan: https://docs.pytorch.org/beginner/mosaic_memory_profiling_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/fx_profiling_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/memory_format_tutorial.html
# [2] Scan: https://docs.pytorch.org/advanced/cpp_frontend.html
# [2] Scan: https://docs.pytorch.org/advanced/custom_ops_landing_page.html
# [2] Scan: https://docs.pytorch.org/advanced/python_custom_ops.html
# [2] Scan: https://docs.pytorch.org/intermediate/compiled_autograd_tutorial
# [2] Scan: https://docs.pytorch.org/advanced/cpp_custom_ops.html
# [2] Scan: https://docs.pytorch.org/advanced/cpp_autograd.html
# [2] Scan: https://docs.pytorch.org/advanced/dispatcher.html
# [2] Scan: https://docs.pytorch.org/advanced/extend_dispatcher.html
# [2] Scan: https://docs.pytorch.org/advanced/privateuseone.html
# [2] Scan: https://docs.pytorch.org/intermediate/custom_function_double_backward_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/custom_function_conv_bn_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/forward_ad_usage.html
# [2] Scan: https://docs.pytorch.org/intermediate/jacobians_hessians.html
# [2] Scan: https://docs.pytorch.org/intermediate/ensembling.html
# [2] Scan: https://docs.pytorch.org/intermediate/per_sample_grads.html
# [2] Scan: https://docs.pytorch.org/intermediate/neural_tangent_kernels.html
# [2] Scan: https://docs.pytorch.org/intermediate/tensorboard_profiler_tutorial.html
# [2] Scan: https://docs.pytorch.org/beginner/hyperparameter_tuning_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/parametrizations.html
# [2] Scan: https://docs.pytorch.org/intermediate/pruning_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/optimizer_step_in_backward_tutorial.html
# [2] Scan: https://docs.pytorch.org/advanced/semi_structured_sparse.html
# [2] Scan: https://docs.pytorch.org/intermediate/ax_multiobjective_nas_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/torch_compile_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/torch_compile_full_example.html
# [2] Scan: https://docs.pytorch.org/intermediate/torch_compile_conv_bn_fuser.html
# [2] Scan: https://docs.pytorch.org/intermediate/inductor_debug_cpu.html
# [2] Scan: https://docs.pytorch.org/intermediate/scaled_dot_product_attention_tutorial.html
# [2] Scan: https://docs.pytorch.org/beginner/knowledge_distillation_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/transformer_building_blocks.html
# [2] Scan: https://docs.pytorch.org/beginner/dist_overview.html
# [2] Scan: https://docs.pytorch.org/beginner/ddp_series_intro.html
# [2] Scan: https://docs.pytorch.org/intermediate/model_parallel_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/ddp_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/dist_tuto.html
# [2] Scan: https://docs.pytorch.org/intermediate/TP_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/process_group_cpp_extension_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/rpc_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/rpc_param_server_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/pipelining_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/rpc_async_execution.html
# [2] Scan: https://docs.pytorch.org/advanced/rpc_ddp_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/FSDP_tutorial.html
# [2] Scan: https://docs.pytorch.org/intermediate/TCPStore_libuv_backend.html
# [2] Scan: https://docs.pytorch.org/intermediate/monarch_distributed_tutorial.html
# [2] Scan: https://pytorch.org/executorch/stable/tutorials/export-to-executorch-tutorial.html
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/executorch/stable/running-a-model-cpp-tutorial.html
#    -> Sauvegardé : pytorch_org_executorch_stable_runningamodelcpptutorialhtml.txt (7201 chars)
# [2] Scan: https://docs.pytorch.org/executorch/main/tutorials/devtools-integration-tutorial.html
#    -> Sauvegardé : docs_pytorch_org_executorch_main_tutorials_devtoolsintegrationtutorialhtml.txt (10163 chars)
# [2] Scan: https://pytorch.org/executorch/stable/examples-end-to-end-to-lower-model-to-delegate.html
#    -> Sauvegardé : pytorch_org_executorch_stable_examplesendtoendtolowermodeltodelegatehtml.txt (6560 chars)
# [2] Scan: https://docs.pytorch.org/intermediate/torchrec_intro_tutorial.html
# [2] Scan: https://docs.pytorch.org/advanced/sharding.html
# [2] Scan: https://pytorch.org/examples?utm_source=examples&utm_medium=examples-landing
#    -> Sauvegardé : pytorch_org_examples.txt (3062 chars)
# [2] Scan: https://docs.pytorch.org/beginner/colab.html
# [2] Scan: https://docs.pytorch.org/_sources/index.rst.txt
# [2] Scan: https://docs.pytorch.org/ao
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://docs.pytorch.org/torchrec
# [2] Scan: https://docs.pytorch.org/torchft
# [2] Scan: https://docs.pytorch.org/torchcodec
# [2] Scan: https://docs.pytorch.org/vision
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://docs.pytorch.org/executorch
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://docs.pytorch.org/xla
#    -> Ignoré (Contenu trop court/vide)
# [1] Scan: https://docs.pytorch.org/vision/stable/generated/torchvision.transforms.Compose.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_generated_torchvisiontransformsComposehtml.txt (980 chars)
# [2] Scan: https://pytorch.org/get-started
#    -> Sauvegardé : pytorch_org_getstarted.txt (7647 chars)
# [2] Scan: https://pytorch.org/ecosystem
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/ecosystem/contributor-awards-2024
#    -> Sauvegardé : pytorch_org_ecosystem_contributorawards2024.txt (1046 chars)
# [2] Scan: https://pytorch.org/edge
#    -> Sauvegardé : pytorch_org_edge.txt (894 chars)
# [2] Scan: https://pytorch.org/executorch-overview
# [2] Scan: https://pytorch.org/executorch/stable/index.html
#    -> Sauvegardé : pytorch_org_executorch_stable_indexhtml.txt (1603 chars)
# [2] Scan: https://pytorch.org/pytorch-domains
#    -> Sauvegardé : pytorch_org_pytorchdomains.txt (1948 chars)
# [2] Scan: https://pytorch.org/community-blog
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/videos
# [2] Scan: https://pytorch.org/community-stories
#    -> Sauvegardé : pytorch_org_communitystories.txt (4084 chars)
# [2] Scan: https://pytorch.org/contact-us
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://docs.pytorch.org/vision/stable/index.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_indexhtml.txt (3505 chars)
# [2] Scan: https://docs.pytorch.org/vision/stable/transforms.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_transformshtml.txt (24350 chars)
# [2] Scan: https://docs.pytorch.org/vision/stable/_sources/generated/torchvision.transforms.Compose.rst.txt
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://docs.pytorch.org/vision/stable/_modules/torchvision/transforms/transforms.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable__modules_torchvision_transforms_transformshtml.txt (85926 chars)
# [2] Scan: https://docs.pytorch.org/vision/stable/auto_examples/transforms/plot_custom_transforms.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_auto_examples_transforms_plot_custom_transformshtml.txt (8822 chars)
# [2] Scan: https://docs.pytorch.org/vision/stable/auto_examples/transforms/plot_cutmix_mixup.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_auto_examples_transforms_plot_cutmix_mixuphtml.txt (5415 chars)
# [2] Scan: https://docs.pytorch.org/vision/stable/auto_examples/transforms/plot_rotated_box_transforms.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_auto_examples_transforms_plot_rotated_box_transformshtml.txt (8599 chars)
# [2] Scan: https://docs.pytorch.org/vision/stable/auto_examples/transforms/plot_transforms_e2e.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_auto_examples_transforms_plot_transforms_e2ehtml.txt (7325 chars)
# [2] Scan: https://docs.pytorch.org/vision/stable/auto_examples/transforms/plot_transforms_getting_started.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_auto_examples_transforms_plot_transforms_getting_startedhtml.txt (9281 chars)
# [2] Scan: https://pytorch.org/ecosystem/contributor-awards-2023
#    -> Sauvegardé : pytorch_org_ecosystem_contributorawards2023.txt (886 chars)
# [1] Scan: https://docs.pytorch.org/vision/stable/generated/torchvision.transforms.ToTensor.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_generated_torchvisiontransformsToTensorhtml.txt (659 chars)
# [2] Scan: https://docs.pytorch.org/vision/stable/_sources/generated/torchvision.transforms.ToTensor.rst.txt
#    -> Ignoré (Contenu trop court/vide)
# [1] Scan: https://docs.pytorch.org/vision/stable/generated/torchvision.transforms.Normalize.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_generated_torchvisiontransformsNormalizehtml.txt (734 chars)
# [2] Scan: https://docs.pytorch.org/vision/stable/_sources/generated/torchvision.transforms.Normalize.rst.txt
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://docs.pytorch.org/docs/stable/tensors.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_tensorshtml.txt (17234 chars)
# [1] Scan: https://docs.pytorch.org/vision/stable/generated/torchvision.datasets.CIFAR10.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_generated_torchvisiondatasetsCIFAR10html.txt (759 chars)
# [2] Scan: https://docs.pytorch.org/vision/stable/datasets.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_datasetshtml.txt (6002 chars)
# [2] Scan: https://docs.pytorch.org/vision/stable/_sources/generated/torchvision.datasets.CIFAR10.rst.txt
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://docs.pytorch.org/vision/stable/_modules/torchvision/datasets/cifar.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable__modules_torchvision_datasets_cifarhtml.txt (5832 chars)
# [1] Scan: https://docs.pytorch.org/docs/stable/data.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_datahtml.txt (38762 chars)
# [2] Scan: https://docs.pytorch.org/docs/stable/utils.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_utilshtml.txt (3045 chars)
# [2] Scan: https://docs.pytorch.org/docs/stable/notes/multiprocessing.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_notes_multiprocessinghtml.txt (9344 chars)
# [2] Scan: https://docs.pytorch.org/docs/stable/notes/faq.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_notes_faqhtml.txt (6766 chars)
# [2] Scan: https://docs.pytorch.org/docs/stable/generated/torch.initial_seed.html
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://docs.pytorch.org/docs/stable/notes/cuda.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_notes_cudahtml.txt (72239 chars)
# [2] Scan: https://docs.pytorch.org/docs/stable/generated/torch.Generator.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_generated_torchGeneratorhtml.txt (2949 chars)
# [2] Scan: https://docs.pytorch.org/docs/stable/torch.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_torchhtml.txt (38415 chars)
# [2] Scan: https://docs.pytorch.org/docs/stable/notes/randomness.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_notes_randomnesshtml.txt (7407 chars)
# [2] Scan: https://docs.pytorch.org/docs/stable/generated/torch.nn.parallel.DistributedDataParallel.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_generated_torchnnparallelDistributedDataParallelhtml.txt (25614 chars)
# [2] Scan: https://docs.pytorch.org/docs/stable/_sources/data.md.txt
#    -> Ignoré (Contenu trop court/vide)
# [1] Scan: https://docs.pytorch.org/vision/stable/generated/torchvision.utils.make_grid.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_generated_torchvisionutilsmake_gridhtml.txt (943 chars)
# [2] Scan: https://docs.pytorch.org/vision/stable/utils.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_utilshtml.txt (501 chars)
# [2] Scan: https://docs.pytorch.org/vision/stable/_sources/generated/torchvision.utils.make_grid.rst.txt
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://docs.pytorch.org/vision/stable/_modules/torchvision/utils.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable__modules_torchvision_utilshtml.txt (34534 chars)
# [2] Scan: https://docs.pytorch.org/vision/stable/auto_examples/others/plot_visualization_utils.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_auto_examples_others_plot_visualization_utilshtml.txt (26723 chars)
# [1] Scan: https://docs.pytorch.org/docs/stable/generated/torch.nn.Module.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_generated_torchnnModulehtml.txt (28661 chars)
# [2] Scan: https://docs.pytorch.org/docs/stable/nn.init.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_nninithtml.txt (8080 chars)
# [2] Scan: https://docs.pytorch.org/docs/stable/generated/torch.compile.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_generated_torchcompilehtml.txt (7625 chars)
# [2] Scan: https://docs.pytorch.org/docs/stable/generated/torch.nn.Dropout.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_generated_torchnnDropouthtml.txt (1055 chars)
# [2] Scan: https://docs.pytorch.org/docs/stable/notes/autograd.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_notes_autogradhtml.txt (39559 chars)
# [2] Scan: https://docs.pytorch.org/docs/stable/future_mod.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_future_modhtml.txt (1765 chars)
# [2] Scan: https://docs.pytorch.org/docs/stable/generated/torch.nn.parameter.Parameter.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_generated_torchnnparameterParameterhtml.txt (912 chars)
# [2] Scan: https://docs.pytorch.org/docs/stable/generated/torch.Tensor.share_memory_.html
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://docs.pytorch.org/docs/stable/tensor_attributes.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_tensor_attributeshtml.txt (11922 chars)
# [2] Scan: https://docs.pytorch.org/docs/stable/generated/torch.Tensor.to.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_generated_torchTensortohtml.txt (2832 chars)
# [2] Scan: https://docs.pytorch.org/docs/stable/optim.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_optimhtml.txt (27124 chars)
# [2] Scan: https://docs.pytorch.org/docs/stable/generated/torch.optim.Optimizer.zero_grad.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_generated_torchoptimOptimizerzero_gradhtml.txt (1477 chars)
# [2] Scan: https://docs.pytorch.org/docs/stable/_sources/generated/torch.nn.Module.rst.txt
#    -> Ignoré (Contenu trop court/vide)
# [1] Scan: https://docs.pytorch.org/docs/stable/generated/torch.nn.Conv2d.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_generated_torchnnConv2dhtml.txt (7505 chars)
# ...
# [2] Scan: https://docs.pytorch.org/vision/stable/auto_examples/transforms/plot_transforms_illustrations.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_auto_examples_transforms_plot_transforms_illustrationshtml.txt (10127 chars)
# [1] Scan: https://docs.pytorch.org/vision/stable/generated/torchvision.transforms.RandomHorizontalFlip.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_generated_torchvisiontransformsRandomHorizontalFliphtml.txt (556 chars)
# [2] Scan: https://docs.pytorch.org/vision/stable/_sources/generated/torchvision.transforms.RandomHorizontalFlip.rst.txt
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://docs.pytorch.org/vision/stable/auto_examples/others/plot_scripted_tensor_transforms.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_auto_examples_others_plot_scripted_tensor_transformshtml.txt (4301 chars)
# [2] Scan: https://docs.pytorch.org/vision/stable/auto_examples/transforms/plot_custom_tv_tensors.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_auto_examples_transforms_plot_custom_tv_tensorshtml.txt (4079 chars)
# [1] Scan: https://docs.pytorch.org/vision/stable/generated/torchvision.transforms.Resize.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_generated_torchvisiontransformsResizehtml.txt (3668 chars)
# [2] Scan: https://docs.pytorch.org/vision/stable/_sources/generated/torchvision.transforms.Resize.rst.txt
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://docs.pytorch.org/vision/stable/auto_examples/transforms/plot_keypoints_transforms.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_auto_examples_transforms_plot_keypoints_transformshtml.txt (3280 chars)
# [1] Scan: https://docs.pytorch.org/vision/stable/generated/torchvision.transforms.CenterCrop.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_generated_torchvisiontransformsCenterCrophtml.txt (602 chars)
# [2] Scan: https://docs.pytorch.org/vision/stable/_sources/generated/torchvision.transforms.CenterCrop.rst.txt
#    -> Ignoré (Contenu trop court/vide)
# [1] Scan: https://docs.pytorch.org/vision/stable/generated/torchvision.datasets.ImageFolder.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_generated_torchvisiondatasetsImageFolderhtml.txt (1056 chars)
# [2] Scan: https://docs.pytorch.org/vision/stable/_sources/generated/torchvision.datasets.ImageFolder.rst.txt
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://docs.pytorch.org/vision/stable/_modules/torchvision/datasets/folder.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable__modules_torchvision_datasets_folderhtml.txt (12938 chars)
# [2] Scan: https://docs.pytorch.org/vision/stable/generated/torchvision.datasets.DatasetFolder.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_generated_torchvisiondatasetsDatasetFolderhtml.txt (2599 chars)
# [1] Scan: https://docs.pytorch.org/docs/stable/generated/torch.autograd.grad_mode.set_grad_enabled.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_generated_torchautogradgrad_modeset_grad_enabledhtml.txt (971 chars)
# [2] Scan: https://docs.pytorch.org/docs/stable/_sources/generated/torch.autograd.grad_mode.set_grad_enabled.rst.txt
#    -> Ignoré (Contenu trop court/vide)
# [1] Scan: https://docs.pytorch.org/docs/stable/generated/torch.sum.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_generated_torchsumhtml.txt (1639 chars)
# [2] Scan: https://docs.pytorch.org/docs/stable/_sources/generated/torch.sum.rst.txt
#    -> Erreur: HTTPSConnectionPool(host='docs.pytorch.org', port=443): Read timed out. (read timeout=10)
# [1] Scan: https://docs.pytorch.org/vision/stable/models/generated/torchvision.models.resnet18.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_models_generated_torchvisionmodelsresnet18html.txt (1475 chars)
# [2] Scan: https://docs.pytorch.org/vision/stable/models.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_modelshtml.txt (18994 chars)
# [2] Scan: https://docs.pytorch.org/vision/stable/models/resnet.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable_models_resnethtml.txt (1093 chars)
# [2] Scan: https://docs.pytorch.org/vision/stable/_sources/models/generated/torchvision.models.resnet18.rst.txt
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://docs.pytorch.org/vision/stable/_modules/torchvision/models/resnet.html
#    -> Sauvegardé : docs_pytorch_org_vision_stable__modules_torchvision_models_resnethtml.txt (38985 chars)
# [1] Scan: https://docs.pytorch.org/docs/stable/generated/torch.optim.lr_scheduler.StepLR.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_generated_torchoptimlr_schedulerStepLRhtml.txt (2226 chars)
# [2] Scan: https://docs.pytorch.org/docs/stable/generated/torch.optim.Optimizer.step.html
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://docs.pytorch.org/docs/stable/_sources/generated/torch.optim.lr_scheduler.StepLR.rst.txt
#    -> Ignoré (Contenu trop court/vide)
# [1] Scan: https://pytorch.org/docs/notes/autograd.html
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/docs/master/notes/autograd.html
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/docs/notes/versions.html
# [1] Scan: https://pytorch.org/tutorials/intermediate/quantized_transfer_learning_tutorial.html
#    -> Ignoré (Contenu trop court/vide)
# [1] Scan: https://pytorch.org/tutorials/_downloads/74249e7f9f1f398f57ccd094a4f3021b/transfer_learning_tutorial.ipynb
#    -> Ignoré (Contenu trop court/vide)
# [1] Scan: https://pytorch.org/tutorials/_downloads/d923ca53b1bfbeb3c222ae46d65d485e/transfer_learning_tutorial.py
#    -> Ignoré (Contenu trop court/vide)
# [1] Scan: https://pytorch.org/tutorials/_downloads/1baf319766772c6431fef590c87c2d3f/transfer_learning_tutorial.zip
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#    -> Ignoré (Contenu trop court/vide)
# [0] Scan: https://pytorch.org/tutorials/recipes/recipes/defining_a_neural_network.html
#    -> Sauvegardé : pytorch_org_tutorials_recipes_recipes_defining_a_neural_networkhtml.txt (5340 chars)
# [1] Scan: hhttps://pytorch.org/vision/stable/generated/torchvision.datasets.MNIST.html
#    -> Erreur: No connection adapters were found for 'hhttps://pytorch.org/vision/stable/generated/torchvision.datasets.MNIST.html'
# [1] Scan: https://docs.pytorch.org/docs/stable/generated/torch.nn.Dropout2d.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_generated_torchnnDropout2dhtml.txt (1705 chars)
# [2] Scan: https://docs.pytorch.org/docs/stable/_sources/generated/torch.nn.Dropout2d.rst.txt
#    -> Ignoré (Contenu trop court/vide)
# [1] Scan: https://docs.pytorch.org/docs/stable/generated/torch.nn.functional.max_pool2d.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_generated_torchnnfunctionalmax_pool2dhtml.txt (1100 chars)
# [2] Scan: https://docs.pytorch.org/docs/stable/generated/torch.nn.functional.max_unpool2d.html
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://docs.pytorch.org/docs/stable/_sources/generated/torch.nn.functional.max_pool2d.rst.txt
#    -> Ignoré (Contenu trop court/vide)
# [1] Scan: https://docs.pytorch.org/docs/stable/generated/torch.nn.functional.log_softmax.html
#    -> Sauvegardé : docs_pytorch_org_docs_stable_generated_torchnnfunctionallog_softmaxhtml.txt (625 chars)
# [2] Scan: https://docs.pytorch.org/docs/stable/_sources/generated/torch.nn.functional.log_softmax.rst.txt
#    -> Ignoré (Contenu trop court/vide)
# [1] Scan: https://pytorch.org/tutorials/recipes/recipes/what_is_state_dict.html
#    -> Sauvegardé : pytorch_org_tutorials_recipes_recipes_what_is_state_dicthtml.txt (3570 chars)
# [2] Scan: https://pytorch.org/tutorials/recipes/recipes/saving_and_loading_models_for_inference.html
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/tutorials/recipes/recipes/saving_and_loading_a_general_checkpoint.html
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/tutorials/_downloads/597dbaac5c207608e108534fea081ff9/what_is_state_dict.ipynb
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/tutorials/_downloads/c087bb345bbf8da823696bf30d4cf850/what_is_state_dict.py
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://pytorch.org/tutorials/_downloads/7eec06ac2cdf546b53c11d8fa75af1da/what_is_state_dict.zip
#    -> Ignoré (Contenu trop court/vide)
# [1] Scan: https://pytorch.org/tutorials/_downloads/f8cb9bf90ebfb30e3e9f9cedbd7ca1d2/defining_a_neural_network.ipynb
#    -> Ignoré (Contenu trop court/vide)
# [1] Scan: https://pytorch.org/tutorials/_downloads/b3632e56edb5b0f9fea092712ede0776/defining_a_neural_network.py
#    -> Ignoré (Contenu trop court/vide)
# [1] Scan: https://pytorch.org/tutorials/_downloads/db77c914bd994e484a1717e0fb16ad03/defining_a_neural_network.zip
#    -> Ignoré (Contenu trop court/vide)
# [0] Scan: https://cs231n.github.io/convolutional-networks/
#    -> Sauvegardé : cs231n_github_io_convolutionalnetworks.txt (50524 chars)
# [0] Scan: https://cs231n.github.io/neural-networks-1/
#    -> Sauvegardé : cs231n_github_io_neuralnetworks1.txt (26677 chars)
# [0] Scan: https://cs231n.github.io/neural-networks-2/
#    -> Sauvegardé : cs231n_github_io_neuralnetworks2.txt (31295 chars)
# [0] Scan: https://cs231n.github.io/optimization-1/
#    -> Sauvegardé : cs231n_github_io_optimization1.txt (23550 chars)
# [0] Scan: http://introtodeeplearning.com/
#    -> Sauvegardé : introtodeeplearning_com_home.txt (6642 chars)
# [0] Scan: https://machinelearningmastery.com/convolutional-layers-for-deep-learning-neural-networks/
# [0] Scan: https://machinelearningmastery.com/how-to-develop-a-cnn-from-scratch-for-cifar-10-photo-classification/
# [0] Scan: https://machinelearningmastery.com/image-augmentation-deep-learning-keras/
# [0] Scan: https://paperswithcode.com/method/cnn
#    -> Erreur: HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out.
# [0] Scan: https://paperswithcode.com/method/resnet
#    -> Erreur: HTTPSConnectionPool(host='paperswithcode.com', port=443): Read timed out. (read timeout=10)
# [0] Scan: https://mlco2.github.io/codecarbon/usage.html
#    -> Sauvegardé : mlco2_github_io_codecarbon_usagehtml.txt (8927 chars)
# [1] Scan: https://mlco2.github.io/codecarbon/index.html
#    -> Sauvegardé : mlco2_github_io_codecarbon_indexhtml.txt (1481 chars)
# [2] Scan: https://mlco2.github.io/codecarbon/_sources/index.rst.txt
#    -> Erreur: HTTPSConnectionPool(host='mlco2.github.io', port=443): Read timed out. (read timeout=10)
# [2] Scan: https://mlco2.github.io/codecarbon/motivation.html
#    -> Sauvegardé : mlco2_github_io_codecarbon_motivationhtml.txt (1820 chars)
# [2] Scan: https://mlco2.github.io/codecarbon/methodology.html
#    -> Sauvegardé : mlco2_github_io_codecarbon_methodologyhtml.txt (12576 chars)
# [2] Scan: https://mlco2.github.io/codecarbon/rapl.html
#    -> Sauvegardé : mlco2_github_io_codecarbon_raplhtml.txt (13741 chars)
# [2] Scan: https://mlco2.github.io/codecarbon/model_examples.html
#    -> Sauvegardé : mlco2_github_io_codecarbon_model_exampleshtml.txt (1176 chars)
# [2] Scan: https://mlco2.github.io/codecarbon/faq.html
#    -> Sauvegardé : mlco2_github_io_codecarbon_faqhtml.txt (4055 chars)
# [2] Scan: https://mlco2.github.io/codecarbon/installation.html
#    -> Sauvegardé : mlco2_github_io_codecarbon_installationhtml.txt (1001 chars)
# [2] Scan: https://mlco2.github.io/codecarbon/api.html
#    -> Sauvegardé : mlco2_github_io_codecarbon_apihtml.txt (1357 chars)
# [2] Scan: https://mlco2.github.io/codecarbon/parameters.html
#    -> Sauvegardé : mlco2_github_io_codecarbon_parametershtml.txt (1087 chars)
# [2] Scan: https://mlco2.github.io/codecarbon/examples.html
#    -> Erreur: HTTPSConnectionPool(host='mlco2.github.io', port=443): Read timed out. (read timeout=10)
# [2] Scan: https://mlco2.github.io/codecarbon/comet.html
#    -> Sauvegardé : mlco2_github_io_codecarbon_comethtml.txt (1628 chars)
# [2] Scan: https://mlco2.github.io/codecarbon/advanced_installation.html
#    -> Sauvegardé : mlco2_github_io_codecarbon_advanced_installationhtml.txt (4273 chars)
# [2] Scan: https://mlco2.github.io/codecarbon/output.html
#    -> Sauvegardé : mlco2_github_io_codecarbon_outputhtml.txt (3278 chars)
# [2] Scan: https://mlco2.github.io/codecarbon/to_logger.html
#    -> Sauvegardé : mlco2_github_io_codecarbon_to_loggerhtml.txt (2382 chars)
# [2] Scan: https://mlco2.github.io/codecarbon/visualize.html
#    -> Sauvegardé : mlco2_github_io_codecarbon_visualizehtml.txt (2641 chars)
# [2] Scan: https://mlco2.github.io/codecarbon/genindex.html
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://mlco2.github.io/codecarbon/py-modindex.html
# [2] Scan: https://mlco2.github.io/codecarbon/search.html
#    -> Ignoré (Contenu trop court/vide)
# [1] Scan: https://mlco2.github.io/codecarbon/_sources/usage.rst.txt
#    -> Ignoré (Contenu trop court/vide)
# [0] Scan: https://huggingface.co/docs/transformers/tasks/image_classification
#    -> Sauvegardé : huggingface_co_docs_transformers_tasks_image_classification.txt (9386 chars)
# [1] Scan: https://huggingface.co/docs/transformers/model_doc/vit
#    -> Sauvegardé : huggingface_co_docs_transformers_model_doc_vit.txt (31937 chars)
# [2] Scan: https://huggingface.co/google?search_models=vit
#    -> Sauvegardé : huggingface_co_google.txt (7493 chars)
# [2] Scan: https://huggingface.co/docs/transformers/v5.0.0/en/model_doc/auto
#    -> Sauvegardé : huggingface_co_docs_transformers_v500_en_model_doc_auto.txt (375408 chars)
# [2] Scan: https://huggingface.co/docs/transformers/v5.0.0/en/model_doc/vit
#    -> Sauvegardé : huggingface_co_docs_transformers_v500_en_model_doc_vit.txt (31937 chars)
# [2] Scan: https://huggingface.co/docs/transformers/v5.0.0/en/main_classes/model
#    -> Sauvegardé : huggingface_co_docs_transformers_v500_en_main_classes_model.txt (37185 chars)
# [2] Scan: https://huggingface.co/docs/transformers/v5.0.0/en/model_doc/fuyu
#    -> Sauvegardé : huggingface_co_docs_transformers_v500_en_model_doc_fuyu.txt (31706 chars)
# [2] Scan: https://huggingface.co/docs/transformers/model_doc/upernet
#    -> Sauvegardé : huggingface_co_docs_transformers_model_doc_upernet.txt (14213 chars)
# [2] Scan: https://huggingface.co/docs/transformers/model_doc/vitdet
#    -> Sauvegardé : huggingface_co_docs_transformers_model_doc_vitdet.txt (11905 chars)
# [1] Scan: https://huggingface.co/spaces/evaluate-metric/accuracy
#    -> Sauvegardé : huggingface_co_spaces_evaluatemetric_accuracy.txt (1274 chars)
# [1] Scan: https://huggingface.co/docs/transformers/training
#    -> Sauvegardé : huggingface_co_docs_transformers_training.txt (5302 chars)
# [0] Scan: https://poloclub.github.io/cnn-explainer/
#    -> Ignoré (Contenu trop court/vide)
# [0] Scan: https://distill.pub/2017/feature-visualization/
#    -> Ignoré (Contenu trop court/vide)
# [0] Scan: https://iq.opengenus.org/vgg16/
#    -> Sauvegardé : iq_opengenus_org_vgg16.txt (1613 chars)
# [1] Scan: https://iq.opengenus.org/content/images/2019/01/vgg_layers.png
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#    -> Ignoré (Contenu trop court/vide)
# [0] Scan: https://iq.opengenus.org/resnet50-architecture/
#    -> Sauvegardé : iq_opengenus_org_resnet50architecture.txt (6047 chars)
# [1] Scan: https://iq.opengenus.org/resnet50-architecture/(https:/iq.opengenus.org/floating-point-operations-per-second-flops-of-machine-learning-models/)
# [1] Scan: https://iq.opengenus.org/convolutional-neural-networks/
#    -> Sauvegardé : iq_opengenus_org_convolutionalneuralnetworks.txt (5080 chars)
# [2] Scan: https://iq.opengenus.org/content/images/2018/10/CNN.png
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://iq.opengenus.org/artificial-neural-networks/
#    -> Sauvegardé : iq_opengenus_org_artificialneuralnetworks.txt (9646 chars)
# [2] Scan: https://twitter.com/share?text=You will love this article on Convolutional%20Neural%20Networks%20(CNN)&url=https://iq.opengenus.org/convolutional-neural-networks/
#    -> Ignoré (Contenu trop court/vide)
# [2] Scan: https://www.facebook.com/sharer/sharer.php?u=https://iq.opengenus.org/convolutional-neural-networks/
# [0] Scan: https://iq.opengenus.org/mobile-net-architecture/
#
# Terminé ! 380 pages extraites avec succès.
